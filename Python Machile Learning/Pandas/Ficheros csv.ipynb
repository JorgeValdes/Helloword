# %%
#Pandas con ficheros de Excel
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\cooke\\Desktop\\Helloworld\\Machile Learning\\Pandas'

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 4032-D651
#
#  Directorio de C:\Users\cooke\Desktop\Helloworld\Machile Learning\Pandas
#
# 08-03-2020  00:59    <DIR>          .
# 08-03-2020  00:59    <DIR>          ..
# 08-03-2020  00:55    <DIR>          .ipynb_checkpoints
# 08-03-2020  00:18             6.650 Agrupacion de los Datos.ipynb
# 08-03-2020  00:59           439.808 BD-Inmuebles.xls
# 08-03-2020  00:36             6.988 Combinar Dataframes.ipynb
# 07-03-2020  23:46            13.031 Dataframe Seleccion de Datos.ipynb
# 07-03-2020  23:28            20.246 Dataframes.ipynb
# 08-03-2020  00:59             1.893 Ficheros csv.ipynb
# 07-03-2020  21:01             2.751 Introduccion a Pandas.ipynb
# 08-03-2020  00:48             6.271 Join con Dataframes.ipynb
# 08-03-2020  00:41             3.473 Merge de Daframes.ipynb
# 08-03-2020  00:00             9.662 Modificar nombre de las filas.ipynb
# ...

# %%
dataframe = pd.read_excel('BD-Inmuebles.xls')

# %%
lista = np.arange(0,3337)
#dataframe['nuevo'] = 
lista
# Out:
# array([   0,    1,    2, ..., 3334, 3335, 3336])

# %%
dataframe.index
# Out:
# RangeIndex(start=0, stop=3337, step=1)

# %%
dataframe['nuevo'] = lista

# %%
dataframe
# Out:
#       Referencia Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida         291
# 1              2 2004-01-01       Local     Venta     Girona         199
# 2              3 2004-01-01     Oficina  Alquiler     Girona          82
# 3              4 2004-01-02     Parking  Alquiler     Girona         285
# 4              5 2004-01-02       Suelo     Venta  Tarragona         152
# 5              6 2004-01-03  Industrial  Alquiler     Girona         131
# 6              7 2004-01-03     Parking  Alquiler  Tarragona          69
# 7              8 2004-01-03     Oficina     Venta     Girona         235
# 8              9 2004-01-04        Piso  Alquiler     Lleida         108
# 9             10 2004-01-04     Parking     Venta     Lleida         299
# 10            11 2004-01-04     Oficina  Alquiler     Girona         124
# 11            12 2004-01-04  Industrial     Venta     Girona         187
# ...

# %%
dataframe.to_excel('BD-Inmuebles.xlsx', sheet_name='Hoja1')

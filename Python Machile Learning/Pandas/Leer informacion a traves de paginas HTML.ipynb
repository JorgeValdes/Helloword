# %%
import pandas as pd
import numpy as np

# %%
pagina_web = 'https://www.facebook.com/jorgeignacio.valdesflores'

# %%
pagina_web
# Out:
# 'https://www.facebook.com/jorgeignacio.valdesflores'

# %%
datos = pd.read_html(pagina_web)

# %%
datos
# Out:
# [                               0                      1   2
#  0  Correo electrónico o teléfono             Contraseña NaN
#  1                            NaN                    NaN NaN
#  2                            NaN  ¿Olvidaste tu cuenta? NaN,
#                       0                                                  1
#  0               Música                                           Don Omar
#  1                  NaN                                                NaN
#  2               Libros                                      Libros En PDF
#  3                  NaN                                                NaN
#  4            Películas                                       El sustituto
#  5                  NaN                                                NaN
#  6           Televisión                     ~*Tres metros sobre el cielo*~
#  7                  NaN                                                NaN
# ...

# %%
dataframe = datos[0]

# %%
dataframe.head(10)
# Out:
#     № País (o territorio dependiente)  \
# 0   1                      China[13]​
# 1   2                           India
# 2   3                  Estados Unidos
# 3   4                       Indonesia
# 4   5                        Pakistán
# 5   6                         Nigeria
# 6   7                          Brasil
# 7   8                       Bangladés
# 8   9                      Rusia[14]​
# 9  10                          México
#
#   Proyecciónexponencialde lapoblaciónal1/1/2020[8]​ % deltotalmun-dial  \
# 0                                     1 404 959 000               1816
# 1                                     1 398 496 000               1808
# 2                                       330 641 000                427
# 3                                       269 856 000                349
# 4                                       222 017 000                287
# 5                                       216 274 000                280
# ...

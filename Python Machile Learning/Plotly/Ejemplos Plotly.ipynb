# %% [markdown]
# Plotly
#
# una libreria de visualizacion interactica

# %%
import pandas as pd
import numpy as np

# %%
import cufflinks as cd
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
cf.go_offline()
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fa1e4c75b216> in <module>
# ----> 1 cf.go_offline()
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#
# NameError: name 'cf' is not defined

# %%
dataframe = pd.DataFrame(np.random.randn(100,4), columns=['a','b','c','d'])

# %%
dataframe
# Out:
#            a         b         c         d
# 0   0.713786 -0.876806  2.021505 -0.223079
# 1  -1.185616  0.196394  0.108478  0.485699
# 2  -0.801509 -1.953575  0.387074 -0.663281
# 3  -0.558537 -0.045333 -0.437048  0.767231
# 4  -0.102678  0.209573  0.169174 -1.555124
# 5  -0.831202 -0.831414  1.587099 -3.404665
# 6  -0.565196 -0.957802  1.489716  0.320279
# 7   0.851018 -0.315889 -1.374745  0.748224
# 8  -1.247717 -0.009242 -1.221516 -0.233426
# 9  -0.238955 -2.721416  1.135789 -0.052648
# 10 -0.834058  0.844298  0.306522 -1.021996
# 11 -0.455094 -0.046315 -1.652908 -0.280281
# 12 -1.393633 -1.125702 -0.152703 -0.282747
# 13 -1.712037 -1.002123 -0.048232 -0.051378
# 14 -0.034724 -0.896961 -0.655412 -1.267511
# 15  0.633783  1.158124 -1.139750 -1.877797
# 16  1.966929  1.816812  0.822555  1.278324
# 17  0.525886 -0.902280 -1.107440 -0.731383
# 18  0.230940  0.944895 -1.114070 -0.173925
# 19  2.228478 -0.460224  0.321725  0.656517
# 20  0.153270  0.132698  0.826139  0.319646
# ...

# %%
dataframe.plot()

# %%
dataframe.iplot()
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-9-9a3a0d44485d> in <module>
# ----> 1 dataframe.iplot()
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1216 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
# ...

# %%
dataframe.iplot(kind='scatter', x='a', y='b', mode='markers')
